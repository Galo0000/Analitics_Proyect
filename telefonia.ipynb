# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_profiling as pp
import pandas as pd
import glob
from IPython.display import display
import numpy as np

# %%
folder_path = 'Telefonia Fija'
dataframes = {'name':[],'dataframe':[]}
csv_files = glob.glob(folder_path + '\\*.csv')
for file_path in csv_files:
    file_name = file_path.split('\\')[-1]
    df = pd.read_csv(f'./Telefonia Fija/{file_name}')
    print(file_name)
    display(df)
    dataframes['name'].append(file_name[:-7])
    dataframes['dataframe'].append(df)
#print(dataframes)
# Out:
# Accesos_telefonía_fija_por_provincia-hogares-comercios-gobierno-otros.csv
#       Año  Trimestre            Provincia Accesos telefonía fija (total)  \
# 0    2022          1         Buenos Aires                      3.340.707
# 1    2022          1      Capital Federal                      1.508.031
# 2    2022          1            Catamarca                         30.167
# 3    2022          1                Chaco                         84.847
# 4    2022          1               Chubut                         72.602
# ..    ...        ...                  ...                            ...
# 787  2014          1           Santa Cruz                         40.625
# 788  2014          1             Santa Fe                        770.361
# 789  2014          1  Santiago del Estero                         70.717
# 790  2014          1     Tierra del Fuego                         32.631
# 791  2014          1              Tucumán                        210.917
#
#     Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# 0                          3.044.152                             230.980
# 1                          1.374.162                             104.267
# 2                             27.489                               2.086
# 3                             77.315                               5.866
# 4                             66.157                               5.020
# ..                               ...                                 ...
# 787                           33.555                               4.528
# 788                          636.284                              85.867
# 789                           58.409                               7.882
# 790                           26.951                               3.637
# 791                          174.209                              23.509
#
#      Accesos telefonía fija (gobierno)  Accesos telefonía fija (otros)
# 0                               14.831                          50.744
# 1                                6.695                          22.907
# 2                              134.000                         458.000
# 3                              377.000                           1.289
# 4                              322.000                           1.103
# ..                                 ...                             ...
# 787                            131.000                           2.411
# 788                              2.491                          45.719
# 789                            229.000                           4.197
# 790                            106.000                           1.937
# 791                            682.000                          12.517
#
# [792 rows x 8 columns]
# Ingresos_trimestrales_telefonía fija.csv
#      Año  Trimestre Ingresos (miles de $)
# 0   2014          1          2.916.071,75
# 1   2014          2           2.974.865,2
# 2   2014          3          3.105.462,02
# 3   2014          4           3.339.690,9
# 4   2015          1          3.260.124,75
# 5   2015          2          3.425.518,48
# 6   2015          3          3.590.883,18
# 7   2015          4          3.815.364,12
# 8   2016          1          4.198.260,39
# 9   2016          2          4.718.769,82
# 10  2016          3          4.951.967,66
# 11  2016          4          4.964.596,39
# 12  2017          1          6.375.681,76
# 13  2017          2          6.970.617,22
# 14  2017          3          6.667.943,53
# 15  2017          4          5.514.336,19
# 16  2018          1          8.252.279,99
# 17  2018          2          7.911.723,07
# 18  2018          3         10.111.350,57
# 19  2018          4          8.997.157,88
# 20  2019          1         12.238.568,39
# 21  2019          2         14.181.055,21
# 22  2019          3         13.404.569,15
# 23  2019          4         20.321.577,16
# 24  2020          1         17.067.597,82
# 25  2020          2         21.035.522,89
# 26  2020          3         18.162.023,89
# 27  2020          4         19.750.303,98
# 28  2021          1         21.378.667,68
# 29  2021          2         22.178.751,89
# 30  2021          3         20.789.995,21
# 31  2021          4         40.616.059,17
# 32  2022          1         24.881.132,36
# Penetracion_trimestral_telefonia_fija_por_provincia.csv
#       Año  Trimestre            Provincia  \
# 0    2014          1         Buenos Aires
# 1    2014          1      Capital Federal
# 2    2014          1            Catamarca
# 3    2014          1                Chaco
# 4    2014          1               Chubut
# ..    ...        ...                  ...
# 787  2022          1           Santa Cruz
# 788  2022          1             Santa Fe
# 789  2022          1  Santiago del Estero
# 790  2022          1     Tierra del Fuego
# 791  2022          1              Tucumán
#
#      Accesos telefonía fija por cada 100 hab  \
# 0                                      26.72
# 1                                      52.66
# 2                                      10.03
# 3                                       9.09
# 4                                      17.66
# ..                                       ...
# 787                                     7.43
# 788                                    17.84
# 789                                     6.93
# 790                                    12.54
# 791                                    10.96
#
#      Accesos telefonía fija por cada 100 hogares
# 0                                          85.26
# 1                                         128.57
# 2                                          39.45
# 3                                          34.02
# 4                                          57.59
# ..                                           ...
# 787                                        24.98
# 788                                        56.72
# 789                                        27.91
# 790                                        42.30
# 791                                        44.25
#
# [792 rows x 5 columns]
# Penetración_provincial_telefonia_fija_accesos_cada_100_hogares.csv
#       Año  Trimestre            Provincia  \
# 0    2014          1         Buenos Aires
# 1    2014          1      Capital Federal
# 2    2014          1            Catamarca
# 3    2014          1                Chaco
# 4    2014          1               Chubut
# ..    ...        ...                  ...
# 787  2022          1           Santa Cruz
# 788  2022          1             Santa Fe
# 789  2022          1  Santiago del Estero
# 790  2022          1     Tierra del Fuego
# 791  2022          1              Tucumán
#
#     Accesos telefonía fija por cada 100 hab  \
# 0                                     26,72
# 1                                     52,66
# 2                                     10,03
# 3                                      9,09
# 4                                     17,66
# ..                                      ...
# 787                                    7,43
# 788                                   17,84
# 789                                    6,93
# 790                                   12,54
# 791                                   10,96
#
#     Accesos telefonía fija por cada 100 hogares
# 0                                         85,26
# 1                                        128,57
# 2                                         39,45
# 3                                         34,02
# 4                                         57,59
# ..                                          ...
# 787                                       24,98
# 788                                       56,72
# 789                                       27,91
# 790                                        42,3
# 791                                       44,25
#
# [792 rows x 5 columns]
# Penetración_total_nacional_telefonía_fija_por_trimestre.csv
#      Año  Trimestre Accesos telefonía fija por cada 100 hab  \
# 0   2022          1                                   16,96
# 1   2021          4                                   16,74
# 2   2021          3                                   15,41
# 3   2021          2                                   15,62
# 4   2021          1                                   15,92
# 5   2020          4                                   16,16
# 6   2020          3                                   16,35
# 7   2020          2                                   16,46
# 8   2020          1                                    16,7
# 9   2019          4                                    17,2
# 10  2019          3                                   17,53
# 11  2019          2                                   18,11
# 12  2019          1                                   18,59
# 13  2018          4                                   21,95
# 14  2018          3                                   21,75
# 15  2018          2                                   21,77
# 16  2018          1                                    21,8
# 17  2017          4                                   23,44
# 18  2017          3                                    23,2
# 19  2017          2                                   23,83
# 20  2017          1                                   23,57
# 21  2016          4                                   23,44
# 22  2016          3                                    23,2
# 23  2016          2                                   23,83
# 24  2016          1                                   23,57
# 25  2015          4                                   23,03
# 26  2015          3                                   23,26
# 27  2015          2                                   23,18
# 28  2015          1                                   23,47
# 29  2014          4                                   22,61
# 30  2014          3                                   22,49
# 31  2014          2                                    22,4
# 32  2014          1                                   22,49
#
#    Accesos telefonía fija por cada 100 hogares
# 0                                        54,71
# 1                                        53,88
# 2                                        49,64
# 3                                        50,35
# 4                                        51,36
# 5                                        52,03
# 6                                        52,68
# 7                                        53,06
# 8                                        53,89
# 9                                        55,55
# 10                                       56,66
# 11                                       58,55
# 12                                       60,16
# 13                                       71,07
# 14                                       70,49
# 15                                       70,78
# 16                                       70,74
# 17                                       76,32
# 18                                       75,53
# 19                                       77,65
# 20                                       76,86
# 21                                       76,32
# 22                                       75,53
# 23                                       77,65
# 24                                       76,86
# 25                                       75,17
# 26                                       76,03
# 27                                       75,87
# 28                                       76,89
# 29                                       74,16
# 30                                       73,86
# 31                                       73,65
# 32                                       74,04
